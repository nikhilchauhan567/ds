# %% [markdown]
# ![image.png](attachment:c6a4458e-3db7-4d80-98c6-2be9a27c7674.png)

# %% [markdown]
# # Problem Description
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape.<br> By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience.<br> The analysis will provide valuable insights and recommendations for stakeholders in the education sector.<br>
# **Data Description**<br>
# •	**Names**: Names of various university and colleges<br>
# •	**Apps**: Number of applications received<br>
# •	**Accept**: Number of applications accepted<br>
# •	**Enroll**: Number of new students enrolled<br>
# •	**Top10perc**: Percentage of new students from top 10% of Higher Secondary class<br>
# •	**Top25perc**: Percentage of new students from top 25% of Higher Secondary class<br>
# •	**F.Undergrad**: Number of full-time undergraduate students<br>
# •	**P.Undergrad**: Number of part-time undergraduate students<br>
# •	**Outstate**: Number of students for whom the particular college or university is Out-of-state tuition<br>
# •	**Room.Board**: Cost of Room and board<br>
# •	**Books**: Estimated book costs for a student<br>
# •	**Personal**: Estimated personal spending for a student<br>
# •	**PhD**: Percentage of faculties with Ph.D.’s<br>
# •	**Terminal**: Percentage of faculties with terminal degree<br>
# •	**S.F.Ratio**: Student/faculty ratio<br>
# •	**perc.alumni**: Percentage of alumni who donate<br>
# •	**Expend**: The Instructional expenditure per student<br>
# •	**Grad.Rate**: Graduation rate<br>

# %% [markdown]
# ## Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## loading dataset

# %%
df=pd.read_csv('Education.csv')

# %% [markdown]
# # Basic Exploration

# %%
df.head()
# Out:
#                           Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 0  Abilene Christian University  1660.0    1232   721.0       23.0         52
# 1            Adelphi University  2186.0    1924   512.0       16.0         29
# 2                Adrian College  1428.0    1097   336.0       22.0         50
# 3           Agnes Scott College   417.0     349     NaN       60.0         89
# 4     Alaska Pacific University   193.0     146    55.0       16.0         44
#
#    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0         2885          537      7440        3300    450    2200.0   70
# 1         2683         1227     12280        6450    750    1500.0   29
# 2         1036           99     11250        3750    400    1165.0   53
# 3          510           63     12960        5450    450     875.0   92
# 4          249          869      7560        4120    800    1500.0   76
#
#    Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# ...

# %% [markdown]
# * *Based on the above result we can observe that the following columns of 'Enroll' and 'S.F.Ratio' have some missing value and incorrect value as:*
#
# * *'Enroll'* have a value of *'NaN'* on index *3*.
# * *'S.F.Ratio'* have a incorrect value as *'?'* on index *'1'*.

# %% [markdown]
# Replacing **?** with **NaN**

# %%
df.replace('?',np.nan,inplace=True)

# %% [markdown]
# ![image.png](attachment:52d501f1-a561-4ae2-a63a-ce45f59448fc.png)

# %%
df.tail()
# Out:
#                               Names     Apps  Accept  Enroll  Top10perc  \
# 772         Worcester State College   2197.0    1515   543.0        4.0
# 773               Xavier University   1959.0    1805   695.0       24.0
# 774  Xavier University of Louisiana   2097.0    1915   695.0       34.0
# 775                 Yale University  10705.0    2453  1317.0       95.0
# 776    York College of Pennsylvania   2989.0    1855   691.0       28.0
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# ...

# %%
df.shape
# Out:
# (777, 18)

# %% [markdown]
# Dataset contains **777 rows** and **18 columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        777 non-null    object
#  1   Apps         775 non-null    float64
#  2   Accept       777 non-null    int64
#  3   Enroll       775 non-null    float64
#  4   Top10perc    773 non-null    float64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     774 non-null    float64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    774 non-null    object
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# ...

# %% [markdown]
# Data type of **S.F.Ratio** should be **Float**

# %%
df['S.F.Ratio']=df['S.F.Ratio'].astype(float)

# %% [markdown]
# ![image.png](attachment:3c5e4b7d-d492-4609-8180-603a4bfce201.png)

# %%
df.isnull().sum()
# Out:
# Names          0
# Apps           2
# Accept         0
# Enroll         2
# Top10perc      4
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       3
# PhD            0
# Terminal       0
# S.F.Ratio      3
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    775.000000    777.000000   775.000000  773.000000  777.000000
# mean    3007.592258   2018.804376   780.961290   27.620957   55.796654
# std     3873.414660   2451.113971   930.077779   17.645470   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      778.000000    604.000000   242.500000   15.000000   41.000000
# 50%     1561.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3635.000000   2424.000000   902.500000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   547.875161
# std     4850.420531   1522.431887   4023.016484  1096.696416   167.426237
# ...

# %% [markdown]
# min value of **Books** and **perc.alumni** is 0, which is need to be checked

# %% [markdown]
# **Box Plot**

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %% [markdown]
# **Removing outliers**

# %% [markdown]
# **Since outliers are present so replacing NULL values in Numerical columns with Median**

# %%
df[df.isnull().sum(axis=1)>0]
# Out:
#                                     Names    Apps  Accept  Enroll  Top10perc  \
# 1                      Adelphi University  2186.0    1924   512.0       16.0
# 3                     Agnes Scott College   417.0     349     NaN       60.0
# 9               Alderson-Broaddus College     NaN     498   172.0       21.0
# 41                     Bellarmine College     NaN     707   308.0       39.0
# 81                    Campbell University  2087.0    1339     NaN       20.0
# 102  Central Connecticut State University  4158.0    2532   902.0        NaN
# 103     Central Missouri State University  4681.0    4101  1436.0        NaN
# 128                 College of Notre Dame   344.0     264    97.0        NaN
# 129     College of Notre Dame of Maryland   457.0     356   177.0        NaN
# 166                    Dillard University  1998.0    1376   651.0       41.0
# 175                       Earlham College  1358.0    1006   274.0       35.0
# ...

# %%
median1=df['Apps'].median()
median2=df['Enroll'].median()
median3=df['Top10perc'].median()
median4=df['Personal'].median()
median5=df['S.F.Ratio'].median()

df['Apps'].replace(np.nan,median1,inplace=True)
df['Enroll'].replace(np.nan,median2,inplace=True)
df['Top10perc'].replace(np.nan,median3,inplace=True)
df['Personal'].replace(np.nan,median4,inplace=True)
df['S.F.Ratio'].replace(np.nan,median5,inplace=True)

# %% [markdown]
# **Box Plot after outlier treatment**

# %% [markdown]
# ![image.png](attachment:9373b63a-90ad-45c9-9cb4-7a5063be4be7.png)

# %% [markdown]
# # Application and Enrollment Analysis

# %%
# Calculating the average number of Application recieved by colleges.
avg = round(df['Apps'].mean(),3)
print("average number of applications received by colleges:",avg)
# Out:
# average number of applications received by colleges: 3003.869

# %%
# Calculating the percentage of applications accepted across all colleges.
df['Accept_Rate']=(df['Accept']/df['Apps'])*100
avg = round(df['Accept_Rate'].mean(),2)
print("percentage of applications are accepted on average across all colleges:",avg)
# Out:
# percentage of applications are accepted on average across all colleges: 74.57

# %%
# Calculating the Average Enrollment Rate.
df['Enroll_rate']=(df['Enroll']/df['Accept'])*100
avg =round(df['Enroll_rate'].mean(),2)
print("Average Enrollment Rate:",avg)
# Out:
# Average Enrollment Rate: 41.29

# %%
# Calculating the Highest number of Applications Recieved.
df['Accept'].max()
# Out:
# 26330

# %%
df[df['Accept']==26330]
# Out:
#                         Names     Apps  Accept  Enroll  Top10perc  Top25perc  \
# 483  Rutgers at New Brunswick  48094.0   26330  4520.0       36.0         79
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 483        21401         3712      7410        4748    690    2009.0   90
#
#      Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  Accept_Rate  \
# 483        95       19.5           19   10474         77    54.746954
#
#      Enroll_rate
# 483     17.16673

# %% [markdown]
# ## Academic Excellence

# %%
# Calculate the average percentage of new students from the top 10% of their higher secondary class
avg_top10perc = df['Top10perc'].mean()

# Calculate the average percentage of new students from the top 25% of their higher secondary class
avg_top25perc = df['Top25perc'].mean()

print("Average percentage of new students from the top 10% of their higher secondary class",avg_top10perc)
print("Average percentage of new students from the top 25% of their higher secondary class",avg_top25perc)

# Plotting the scatter plot for Top10perc vs Top25perc
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Top10perc', y='Top25perc', data=df)
plt.title('Correlation between Top 10% and Top 25% of High School Class')
plt.xlabel('Percentage of Students from Top 10%')
plt.ylabel('Percentage of Students from Top 25%')
plt.grid(True)
plt.show()
# Out:
# Average percentage of new students from the top 10% of their higher secondary class 27.597168597168597
# Average percentage of new students from the top 25% of their higher secondary class 55.7966537966538

# %% [markdown]
# The scatter plot shows a positive correlation between Top10perc and Top25perc. This means that colleges with a higher percentage of students from the top 10% of their high school class also tend to have a higher percentage of students from the top 25% of their high school class. This indicates that colleges attracting top-performing students (top 10%) are likely also attracting a broader range of high-performing students (top 25%).

# %% [markdown]
# ## Student Demographics

# %%
# Calculate the average number of full-time undergraduate students per college
avg_full_time_undergrad = df['F.Undergrad'].mean()

# Calculate the average number of part-time undergraduate students per college
avg_part_time_undergrad = df['P.Undergrad'].mean()

# Find the college with the highest number of out-of-state students
college_highest_outstate = df.loc[df['Outstate'].idxmax(), 'Names']

print("Average number of full-time undergraduate students per college:" ,avg_full_time_undergrad)
print("Average number of part-time undergraduate students per college:" ,avg_part_time_undergrad)
print("College with the highest number of out-of-state students: ", college_highest_outstate)
# Out:
# Average number of full-time undergraduate students per college: 3699.907335907336
# Average number of part-time undergraduate students per college: 855.2985842985843
# College with the highest number of out-of-state students:  Bennington College

# %% [markdown]
# ## Cost and Spending

# %%
# Calculate the average cost of room and board across all colleges
avg_room_board = df['Room.Board'].mean()

# Calculate the average estimated book cost for a student
avg_book_cost = df['Books'].mean()

# Calculate the average estimated personal spending for a student
avg_personal_spending = df['Personal'].mean()

# Calculate the variation of instructional expenditure per student across colleges
instructional_expenditure_variation = df['Expend'].describe()

# Print the results
print(f"Average cost of room and board:{avg_room_board:.2f}")
print(f"Average estimated book cost: {avg_book_cost:.2f}")
print(f"Average estimated personal spending: {avg_personal_spending:.2f}")
print("Variation of instructional expenditure per student:")
print(instructional_expenditure_variation)
# Out:
# Average cost of room and board:4357.53
# Average estimated book cost: 547.88
# Average estimated personal spending: 1599.96
# Variation of instructional expenditure per student:
# count      777.000000
# mean      9660.171171
# std       5221.768440
# min       3186.000000
# 25%       6751.000000
# 50%       8377.000000
# 75%      10830.000000
# max      56233.000000
# Name: Expend, dtype: float64

# %% [markdown]
# This reveals a wide range of instructional expenditures per student across different colleges. This indicates significant variability in how much colleges invest in instructional costs per student.

# %% [markdown]
# ## Faculty Qualification

# %%
# Average percentage of faculties with Ph.D.s across all colleges
avg_phd_faculty = df['PhD'].mean()
print(f"Average percentage of faculties with Ph.D.s: {avg_phd_faculty:.2f}%")

# Average percentage of faculties with terminal degrees across all colleges
avg_terminal_faculty = df['Terminal'].mean()
print(f"Average percentage of faculties with terminal degrees: {avg_terminal_faculty:.2f}%")

# Correlation between the percentage of faculties with Ph.D.s and the graduation rate
correlation_phd_grad_rate = df['PhD'].corr(df['Grad.Rate'])
print(f"Correlation between percentage of faculties with Ph.D.s and graduation rate: {correlation_phd_grad_rate:.2f}")
# Plotting the scatter plot with a regression line for percentage of faculties with Ph.D.s vs graduation rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PhD', y='Grad.Rate', data=df)
plt.title('Correlation between Percentage of Faculties with Ph.D.s and Graduation Rate')
plt.xlabel('Percentage of Faculties with Ph.D.s (%)')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()
# Out:
# Average percentage of faculties with Ph.D.s: 72.66%
# Average percentage of faculties with terminal degrees: 79.70%
# Correlation between percentage of faculties with Ph.D.s and graduation rate: 0.31

# %% [markdown]
# ->The scatter plot shows a positive correlation between the percentage of faculties with Ph.D.s and the graduation rate. This means that as the percentage of faculty with Ph.D.s increases, the graduation rate tends to increase as well.<br>
# ->There is considerable variation in graduation rates even among colleges with high percentages of faculty with Ph.D.s. This indicates that while having a higher percentage of Ph.D. faculty might contribute to higher graduation rates

# %% [markdown]
# ## Student-Faculty Interaction

# %%
# Average student/faculty ratio across all colleges
avg_student_faculty_ratio = df['S.F.Ratio'].mean()
print(f"Average student/faculty ratio: {avg_student_faculty_ratio:.2f}")

# College with the lowest student/faculty ratio
college_lowest_sfratio = df.loc[df['S.F.Ratio'].idxmin(), 'Names']
print(f"College with the lowest student/faculty ratio: {college_lowest_sfratio}")

# Correlation between the student/faculty ratio and the graduation rate
correlation_sfratio_grad_rate = df['S.F.Ratio'].corr(df['Grad.Rate'])
print(f"Correlation between student/faculty ratio and graduation rate: {correlation_sfratio_grad_rate:.2f}")
# Plotting the scatter plot for student/faculty ratio vs graduation rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x='S.F.Ratio', y='Grad.Rate', data=df)
plt.title('Correlation between Student/Faculty Ratio and Graduation Rate')
plt.xlabel('Student/Faculty Ratio')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()
# Out:
# Average student/faculty ratio: 14.09
# College with the lowest student/faculty ratio: University of Charleston
# Correlation between student/faculty ratio and graduation rate: -0.30

# %% [markdown]
# ->The scatter plot indicates a negative correlation between the student/faculty ratio and the graduation rate. This means that as the student/faculty ratio increases (i.e., more students per faculty member), the graduation rate tends to decrease.

# %% [markdown]
# ## Alumni Engagement

# %%
# Average percentage of alumni who donate across all colleges
avg_alumni_donate = df['perc.alumni'].mean()
print(f"Average percentage of alumni who donate: {avg_alumni_donate:.2f}%")

# Correlation between the percentage of alumni who donate and the graduation rate
correlation_alumni_grad_rate = df['perc.alumni'].corr(df['Grad.Rate'])
print(f"Correlation between percentage of alumni who donate and graduation rate: {correlation_alumni_grad_rate:.2f}")
# Plotting the scatter plot for percentage of alumni who donate vs graduation rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x='perc.alumni', y='Grad.Rate', data=df)
plt.title('Correlation between Percentage of Alumni Who Donate and Graduation Rate')
plt.xlabel('Percentage of Alumni Who Donate (%)')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()
# Out:
# Average percentage of alumni who donate: 22.74%
# Correlation between percentage of alumni who donate and graduation rate: 0.49

# %% [markdown]
# ->There is noticeable variation in graduation rates for similar percentages of alumni who donate. While the trend indicates that higher alumni donation percentages are associated with higher graduation rates, there are colleges with lower alumni donation percentages that also have high graduation rates.

# %% [markdown]
# ## Graduation Rates

# %%
# Average graduation rate across all colleges
avg_graduation_rate = df['Grad.Rate'].mean()
print(f"Average graduation rate: {avg_graduation_rate:.2f}%")

# College with the highest graduation rate
college_highest_grad_rate = df.loc[df['Grad.Rate'].idxmax(), 'Names']
print(f"College with the highest graduation rate: {college_highest_grad_rate}")

# Correlation between the instructional expenditure per student and the graduation rate
correlation_expend_grad_rate = df['Expend'].corr(df['Grad.Rate'])
print(f"Correlation between instructional expenditure per student and graduation rate: {correlation_expend_grad_rate:.2f}")
# Plotting the scatter plot for instructional expenditure per student vs graduation rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Expend', y='Grad.Rate', data=df)
plt.title('Correlation between Instructional Expenditure per Student and Graduation Rate')
plt.xlabel('Instructional Expenditure per Student ($)')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()
# Out:
# Average graduation rate: 65.46%
# College with the highest graduation rate: Cazenovia College
# Correlation between instructional expenditure per student and graduation rate: 0.39

# %% [markdown]
# ## Overall Insights

# %%
# Calculate correlations between graduation rate and various factors
correlation_matrix = df[['Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc', 'Room.Board', 'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend', 'Grad.Rate']].corr()

# Extract only the correlations with graduation rate
correlation_with_grad_rate = correlation_matrix[['Grad.Rate']].drop('Grad.Rate')

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_with_grad_rate, annot=True, cmap='coolwarm', cbar=True, vmin=-1, vmax=1)
plt.title('Correlation of Various Factors with Graduation Rate')
plt.show()

# %% [markdown]
# **Instructional Expenditure (Expend):**
# There is a positive correlation between instructional expenditure per student and the graduation rate. This suggests that higher investment in instructional resources may contribute to better student outcomes.
#
# **Percentage of Alumni Who Donate (perc.alumni):**
# A positive correlation is observed between the percentage of alumni who donate and the graduation rate. This indicates that higher alumni engagement and donations could be linked to better institutional support and resources, positively impacting graduation rates.
#
# **Student/Faculty Ratio (S.F.Ratio):**
# A negative correlation is observed between the student/faculty ratio and the graduation rate. This implies that lower student/faculty ratios, which provide more individualized attention and support, are associated with higher graduation rates.
#
# **Faculty Qualifications (PhD, Terminal):**
# There are positive correlations between the percentage of faculty with Ph.D.s and terminal degrees and the graduation rate. This suggests that higher faculty qualifications might lead to better educational quality and student success.
#
# **Academic Excellence (Top10perc, Top25perc):**
# Positive correlations exist between the percentages of students in the top 10% and top 25% of their high school classes and the graduation rate. This indicates that colleges with higher percentages of academically excellent students tend to have higher graduation rates.
#
# **Acceptance and Enrollment Metrics (Apps, Accept, Enroll):**
# There are weaker correlations between the number of applications, acceptance rates, and enrollment numbers and the graduation rate. This suggests that these factors are less directly related to graduation outcomes compared to other factors like expenditure and faculty qualifications.
#
# **Out-of-State Students (Outstate):**
# A slight positive correlation is observed between the number of out-of-state students and the graduation rate. This might indicate that institutions attracting a diverse student body from various regions can foster environments conducive to student success.
#
# **Room and Board Costs (Room.Board):**
# There is a slight positive correlation between room and board costs and graduation rates. This could be indicative of higher-cost institutions possibly providing better facilities and support, contributing to higher graduation rates.

# %% [markdown]
# ## Recomendations

# %% [markdown]
# Based on the correlations, we can make recommendations to colleges on how to improve their graduation rates. Higher positive correlation values indicate stronger associations with graduation rates.<br>
# 1.	Enhance Academic Excellence: If correlations with Top10perc and Top25perc are high, colleges should focus on admitting students who performed well in their higher secondary classes.<br>
# 2.	Increase Faculty Qualifications: If PhD and Terminal have high correlations, hiring more qualified faculty members with Ph.D.s and terminal degrees could improve graduation rates.<br>
# 3.	Improve Student-to-Faculty Ratio: A high correlation with S.F.Ratio suggests that maintaining a lower student-to-faculty ratio can positively impact graduation rates, indicating more personalized attention for students.<br>
# 4.	Boost Alumni Engagement: If perc.alumni shows a strong positive correlation, increasing alumni donations and engagement can create better facilities and programs for students, thus improving graduation rates.<br>
# 5.	Increase Instructional Expenditure: A high correlation with Expend indicates that higher spending on instructional materials and resources per student.
